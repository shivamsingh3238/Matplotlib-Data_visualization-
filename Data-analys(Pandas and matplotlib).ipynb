# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_excel('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Data_Files/Canada.xlsx',skiprows=range(20),skipfooter=2)
data.head()#print starting 5 columns
# Out:
#          Type    Coverage          AreaName           RegName  1980  1981  \
# 0  Immigrants    Citizens  Northern America  Northern America    ..    ..
# 1  Immigrants  Foreigners            Africa    Eastern Africa  1471  1641
# 2  Immigrants  Foreigners            Africa     Middle Africa    33    27
# 3  Immigrants  Foreigners            Africa   Northern Africa  1100  1268
# 4  Immigrants  Foreigners            Africa   Southern Africa  1041  1126
#
#    1982  1983  1984  1985  ...   2004   2005   2006   2007   2008   2009  \
# 0    ..    ..    ..    ..  ...     ..     ..     ..     ..     ..     ..
# 1  1426  1094  1187  1134  ...   7726   7083   6750   6669   6705   6922
# 2    44    32    42    30  ...   2452   2802   2834   2951   3034   3255
# 3  1348   936   842   840  ...  12478  11323  12705  11750  13456  16320
# 4   791   387   297   327  ...   1203   1012   1148   1230   1184   1235
#
#     2010   2011   2012  2013
# 0     ..      1      1   NaN
# ...

# %%
data.tail()#print last 5 rows
# Out:
#           Type    Coverage          AreaName                    RegName  1980  \
# 22  Immigrants  Foreigners  Northern America           Northern America  9378
# 23  Immigrants  Foreigners           Oceania  Australia and New Zealand  1304
# 24  Immigrants  Foreigners           Oceania                  Melanesia   632
# 25  Immigrants  Foreigners           Oceania                 Micronesia     1
# 26  Immigrants  Foreigners           Oceania                  Polynesia     5
#
#      1981  1982  1983  1984  1985  ...  2004  2005  2006  2007   2008  2009  \
# 22  10030  9074  7100  6661  6543  ...  6990  8394  9613  9463  10190  8995
# 23   1119   848   457   481   467  ...  1280  1279  1193  1383   1498  1538
# 24    707   816   558   391   448  ...   497   300   278   304    331   313
# 25     ..    ..     1    ..    ..  ...     1     2     1     3      1     2
# 26     13    11     2     6     5  ...    10     4     1     3      4     7
#
#     2010  2011  2012  2013
# ...

# %%
data.info()#vertical view
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 38 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Type      27 non-null     object
#  1   Coverage  27 non-null     object
#  2   AreaName  27 non-null     object
#  3   RegName   23 non-null     object
#  4   1980      27 non-null     object
#  5   1981      27 non-null     object
#  6   1982      27 non-null     object
#  7   1983      27 non-null     object
#  8   1984      27 non-null     object
#  9   1985      27 non-null     object
#  10  1986      27 non-null     object
#  11  1987      27 non-null     object
#  12  1988      27 non-null     object
#  13  1989      27 non-null     object
#  14  1990      27 non-null     object
#  15  1991      27 non-null     object
#  16  1992      27 non-null     object
#  17  1993      27 non-null     int64
#  18  1994      27 non-null     object
#  19  1995      27 non-null     int64
# ...

# %%
data.columns.values#horizontal view
# Out:
# array(['Type', 'Coverage', 'AreaName', 'RegName', 1980, 1981, 1982, 1983,
#        1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994,
#        1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005,
#        2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013], dtype=object)

# %%
print(type(data.columns.tolist())) # convert the columns value into list(array)
# Out:
# <class 'list'>

# %%
data.shape #(rows ,columns)
# Out:
# (27, 38)

# %%
data.drop(['Type', 'Coverage', 'AreaName', 'RegName'],axis=1)
data.head(2)
# Out:
#          Type    Coverage          AreaName           RegName  1980  1981  \
# 0  Immigrants    Citizens  Northern America  Northern America    ..    ..
# 1  Immigrants  Foreigners            Africa    Eastern Africa  1471  1641
#
#    1982  1983  1984  1985  ...  2004  2005  2006  2007  2008  2009  2010  \
# 0    ..    ..    ..    ..  ...    ..    ..    ..    ..    ..    ..    ..
# 1  1426  1094  1187  1134  ...  7726  7083  6750  6669  6705  6922  8591
#
#    2011  2012  2013
# 0     1     1   NaN
# 1  8956  8846   NaN
#
# [2 rows x 38 columns]

# %%
data['total']=data.sum(axis=1)#add coloums 
data.head()#print data
# Out:
#          Type    Coverage          AreaName           RegName  1980  1981  \
# 0  Immigrants    Citizens  Northern America  Northern America    ..    ..
# 1  Immigrants  Foreigners            Africa    Eastern Africa  1471  1641
# 2  Immigrants  Foreigners            Africa     Middle Africa    33    27
# 3  Immigrants  Foreigners            Africa   Northern Africa  1100  1268
# 4  Immigrants  Foreigners            Africa   Southern Africa  1041  1126
#
#    1982  1983  1984  1985  ...   2005   2006   2007   2008   2009   2010  \
# 0    ..    ..    ..    ..  ...     ..     ..     ..     ..     ..     ..
# 1  1426  1094  1187  1134  ...   7083   6750   6669   6705   6922   8591
# 2    44    32    42    30  ...   2802   2834   2951   3034   3255   3369
# 3  1348   936   842   840  ...  11323  12705  11750  13456  16320  19271
# 4   791   387   297   327  ...   1012   1148   1230   1184   1235   1306
#
#     2011   2012 2013     total
# 0      1      1  NaN      30.0
# ...

# %%
data.isnull().sum()
# Out:
# Type         0
# Coverage     0
# AreaName     0
# RegName      4
# 1980         0
# 1981         0
# 1982         0
# 1983         0
# 1984         0
# 1985         0
# 1986         0
# 1987         0
# 1988         0
# 1989         0
# 1990         0
# 1991         0
# 1992         0
# 1993         0
# 1994         0
# 1995         0
# 1996         0
# 1997         0
# 1998         0
# 1999         0
# 2000         0
# 2001         0
# 2002         0
# 2003         0
# 2004         0
# 2005         0
# 2006         0
# 2007         0
# 2008         0
# 2009         0
# 2010         0
# 2011         0
# 2012         0
# 2013        27
# total        0
# dtype: int64

# %%
data.describe() #describe all the max mean and % of data
# Out:
#                1993          1995           1996           2012  2013  \
# count     27.000000     27.000000      27.000000      27.000000   0.0
# mean   16077.555556  13665.481481   14559.333333   18624.925926   NaN
# std    22558.381551  20431.329746   22833.075875   30820.141993   NaN
# min        1.000000      1.000000       1.000000       1.000000   NaN
# 25%     1442.000000   1176.000000    1202.000000    2126.500000   NaN
# 50%     7435.000000   6158.000000    5962.000000    8846.000000   NaN
# 75%    16550.000000  16766.000000   16772.000000   21313.000000   NaN
# max    98737.000000  90424.000000  103030.000000  152218.000000   NaN
#
#               total
# count  2.700000e+01
# mean   3.146365e+05
# std    4.707975e+05
# min    2.500000e+01
# 25%    3.157750e+04
# 50%    1.468750e+05
# 75%    4.562625e+05
# max    2.222045e+06

# %% [markdown]
# # pandas Data slicing

# %%
#select columns or filter on a columns name
